# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv(r"D:\courses\Time_Series\Files\Files for Regression\Data\House_Price.csv",
                  header=0)

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# 1      Lake        42     YES  0.046146
# 2      None        38     YES  0.045764
# 3      Lake        45     YES  0.047151
# 4      Lake        55     YES  0.039474

# %%
data.shape
# Out:
# (506, 19)

# %%
data.describe().T
# Out:
#              count       mean        std        min        25%        50%  \
# price        506.0  22.528854   9.182176   5.000000  17.025000  21.200000
# crime_rate   506.0   3.613524   8.601545   0.006320   0.082045   0.256510
# resid_area   506.0  41.136779   6.860353  30.460000  35.190000  39.690000
# air_qual     506.0   0.554695   0.115878   0.385000   0.449000   0.538000
# room_num     506.0   6.284634   0.702617   3.561000   5.885500   6.208500
# age          506.0  68.574901  28.148861   2.900000  45.025000  77.500000
# dist1        506.0   3.971996   2.108532   1.130000   2.270000   3.385000
# dist2        506.0   3.628775   2.108580   0.920000   1.940000   3.010000
# dist3        506.0   3.960672   2.119797   1.150000   2.232500   3.375000
# dist4        506.0   3.618972   2.099203   0.730000   1.940000   3.070000
# teachers     506.0  21.544466   2.164946  18.000000  19.800000  20.950000
# poor_prop    506.0  12.653063   7.141062   1.730000   6.950000  11.360000
# n_hos_beds   498.0   7.899767   1.476683   5.268000   6.634500   7.999000
# n_hot_rooms  506.0  13.041605   5.238957  10.057600  11.189800  12.720000
# rainfall     506.0  39.181818  12.513697   3.000000  28.000000  39.000000
# parks        506.0   0.054454   0.010632   0.033292   0.046464   0.053507
#
#                    75%         max
# price        25.000000   50.000000
# crime_rate    3.677082   88.976200
# resid_area   48.100000   57.740000
# air_qual      0.624000    0.871000
# room_num      6.623500    8.780000
# age          94.075000  100.000000
# dist1         5.367500   12.320000
# dist2         4.992500   11.930000
# dist3         5.407500   12.320000
# dist4         4.985000   11.940000
# teachers     22.600000   27.400000
# poor_prop    16.955000   37.970000
# n_hos_beds    9.088000   10.876000
# n_hot_rooms  14.170800  101.120000
# rainfall     50.000000   60.000000
# parks         0.061397    0.086711

# %%
sns.jointplot(x='n_hot_rooms', y='price', data=data)

# %%
sns.jointplot(x='rainfall', y='price', data=data)

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# 1      Lake        42     YES  0.046146
# 2      None        38     YES  0.045764
# 3      Lake        45     YES  0.047151
# 4      Lake        55     YES  0.039474

# %%
sns.countplot(x="airport", data=data)

# %%
sns.countplot(x='waterbody', data=data)

# %%
sns.countplot(x='bus_ter', data=data)

# %% [markdown]
# Some of the observations
#
# * Missing values in n_hos_beds
# * Skewness or outliers in crime rate
# * Outliers in n_hot_rooms and rainfall
# * Bus_ter has only 'YES' values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     498 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %% [markdown]
# ## Treating Outliers

# %% [markdown]
# We will use Capping and Flooring.
#
# So 1st we need to identify and the <b>99th</b> & <b>1</b> percentile values of this 2 variables.
#
# The logic is that, if the value is More that <b>99th</b> or Less than <b>1</b> Percentile then it is an outlier

# %%
np.percentile(data.n_hot_rooms,[99])    # Since Outliers is at higher end
# Out:
# array([15.39952])

# %%
# To fetch 1st value in an array

np.percentile(data.n_hot_rooms,[99])[0]
# Out:
# 15.399519999999999

# %%
uv = np.percentile(data.n_hot_rooms,[99])[0]

# %%
data[(data.n_hot_rooms)>uv]       # This will remove outliers
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# 423   2.34   1.87      19.8      23.29      NO       8.268        81.12
#
#     waterbody  rainfall bus_ter     parks
# 2        None        38     YES  0.045764
# 166     River        37     YES  0.052105
# 204     River        51     YES  0.044178
# 267      None        42     YES  0.063235
# 369     River        58     YES  0.067477
# 423      Lake        29     YES  0.063344

# %%
data.n_hot_rooms[(data.n_hot_rooms)>3*uv]
# Out:
# 2      101.12
# 423     81.12
# Name: n_hot_rooms, dtype: float64

# %%
data.n_hot_rooms[(data.n_hot_rooms)>3*uv] = 3*uv
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data[(data.n_hot_rooms)>uv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 166   2.31   1.86      25.3       3.70     YES       8.300     15.40000
# 204   5.28   4.99      25.3       2.88     YES       8.900     15.40000
# 267   2.43   2.52      27.0       7.44     YES       8.000     15.40000
# 369   1.65   0.94      19.8       3.73     YES       6.700     15.40000
# 423   2.34   1.87      19.8      23.29      NO       8.268     46.19856
#
#     waterbody  rainfall bus_ter     parks
# 2        None        38     YES  0.045764
# 166     River        37     YES  0.052105
# 204     River        51     YES  0.044178
# 267      None        42     YES  0.063235
# 369     River        58     YES  0.067477
# 423      Lake        29     YES  0.063344

# %%
np.percentile(data.rainfall,[1])[0]     # Since Outlier is at lower end
# Out:
# 20.0

# %%
lv = np.percentile(data.rainfall,[1])[0]

# %%
data[(data.rainfall)<lv]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
data.rainfall[(data.rainfall)<0.3*lv] = 3*lv
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.jointplot(x="crime_rate", y="price", data=data)

# %%
data.describe().T
# Out:
#              count       mean        std        min        25%        50%  \
# price        506.0  22.528854   9.182176   5.000000  17.025000  21.200000
# crime_rate   506.0   3.613524   8.601545   0.006320   0.082045   0.256510
# resid_area   506.0  41.136779   6.860353  30.460000  35.190000  39.690000
# air_qual     506.0   0.554695   0.115878   0.385000   0.449000   0.538000
# room_num     506.0   6.284634   0.702617   3.561000   5.885500   6.208500
# age          506.0  68.574901  28.148861   2.900000  45.025000  77.500000
# dist1        506.0   3.971996   2.108532   1.130000   2.270000   3.385000
# dist2        506.0   3.628775   2.108580   0.920000   1.940000   3.010000
# dist3        506.0   3.960672   2.119797   1.150000   2.232500   3.375000
# dist4        506.0   3.618972   2.099203   0.730000   1.940000   3.070000
# teachers     506.0  21.544466   2.164946  18.000000  19.800000  20.950000
# poor_prop    506.0  12.653063   7.141062   1.730000   6.950000  11.360000
# n_hos_beds   498.0   7.899767   1.476683   5.268000   6.634500   7.999000
# n_hot_rooms  506.0  12.864050   2.688778  10.057600  11.189800  12.720000
# rainfall     506.0  39.294466  12.443705  20.000000  28.000000  39.500000
# parks        506.0   0.054454   0.010632   0.033292   0.046464   0.053507
#
#                    75%         max
# price        25.000000   50.000000
# crime_rate    3.677082   88.976200
# resid_area   48.100000   57.740000
# air_qual      0.624000    0.871000
# room_num      6.623500    8.780000
# age          94.075000  100.000000
# dist1         5.367500   12.320000
# dist2         4.992500   11.930000
# dist3         5.407500   12.320000
# dist4         4.985000   11.940000
# teachers     22.600000   27.400000
# poor_prop    16.955000   37.970000
# n_hos_beds    9.088000   10.876000
# n_hot_rooms  14.170800   46.198560
# rainfall     50.000000   60.000000
# parks         0.061397    0.086711

# %% [markdown]
# # Handeling Missing Values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     498 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
data.n_hos_beds = data.n_hos_beds.fillna(data.n_hos_beds.mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
# price          506 non-null float64
# crime_rate     506 non-null float64
# resid_area     506 non-null float64
# air_qual       506 non-null float64
# room_num       506 non-null float64
# age            506 non-null float64
# dist1          506 non-null float64
# dist2          506 non-null float64
# dist3          506 non-null float64
# dist4          506 non-null float64
# teachers       506 non-null float64
# poor_prop      506 non-null float64
# airport        506 non-null object
# n_hos_beds     506 non-null float64
# n_hot_rooms    506 non-null float64
# waterbody      506 non-null object
# rainfall       506 non-null int64
# bus_ter        506 non-null object
# parks          506 non-null float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
sns.jointplot(x="crime_rate", y="price", data=data)

# %% [markdown]
# Since most of the values are at 0 and log of it can be lead to -∞
#
# So we have to transform that

# %%
data.crime_rate = np.log(1+data.crime_rate)

# %%
sns.jointplot(x="crime_rate", y="price", data=data)

# %% [markdown]
# There are not outliers in the graph

# %%
data['avg_dist'] = (data.dist1+data.dist2+data.dist3+data.dist4)/4

# %%
data.describe().T
# Out:
#              count       mean        std        min        25%        50%  \
# price        506.0  22.528854   9.182176   5.000000  17.025000  21.200000
# crime_rate   506.0   0.813418   1.022731   0.006300   0.078853   0.228336
# resid_area   506.0  41.136779   6.860353  30.460000  35.190000  39.690000
# air_qual     506.0   0.554695   0.115878   0.385000   0.449000   0.538000
# room_num     506.0   6.284634   0.702617   3.561000   5.885500   6.208500
# age          506.0  68.574901  28.148861   2.900000  45.025000  77.500000
# dist1        506.0   3.971996   2.108532   1.130000   2.270000   3.385000
# dist2        506.0   3.628775   2.108580   0.920000   1.940000   3.010000
# dist3        506.0   3.960672   2.119797   1.150000   2.232500   3.375000
# dist4        506.0   3.618972   2.099203   0.730000   1.940000   3.070000
# teachers     506.0  21.544466   2.164946  18.000000  19.800000  20.950000
# poor_prop    506.0  12.653063   7.141062   1.730000   6.950000  11.360000
# n_hos_beds   506.0   7.899767   1.464939   5.268000   6.659000   7.963000
# n_hot_rooms  506.0  12.864050   2.688778  10.057600  11.189800  12.720000
# rainfall     506.0  39.294466  12.443705  20.000000  28.000000  39.500000
# parks        506.0   0.054454   0.010632   0.033292   0.046464   0.053507
# avg_dist     506.0   3.795104   2.105859   1.127500   2.100625   3.207500
#
#                    75%         max
# price        25.000000   50.000000
# crime_rate    1.542674    4.499545
# resid_area   48.100000   57.740000
# air_qual      0.624000    0.871000
# room_num      6.623500    8.780000
# age          94.075000  100.000000
# dist1         5.367500   12.320000
# dist2         4.992500   11.930000
# dist3         5.407500   12.320000
# dist4         4.985000   11.940000
# teachers     22.600000   27.400000
# poor_prop    16.955000   37.970000
# n_hos_beds    9.076000   10.876000
# n_hot_rooms  14.170800   46.198560
# rainfall     50.000000   60.000000
# parks         0.061397    0.086711
# avg_dist      5.187500   12.127500

# %%
# now we can remove that 4 variables

data.drop(['dist1','dist2','dist3','dist4','bus_ter'], axis = 1)
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  teachers  \
# 0     24.0    0.006300       32.31     0.538     6.575  65.2      24.7
# 1     21.6    0.026944       37.07     0.469     6.421  78.9      22.2
# 2     34.7    0.026924       37.07     0.469     7.185  61.1      22.2
# 3     33.4    0.031857       32.18     0.458     6.998  45.8      21.3
# 4     36.2    0.066770       32.18     0.458     7.147  54.2      21.3
# ..     ...         ...         ...       ...       ...   ...       ...
# 501   22.4    0.060747       41.93     0.573     6.593  69.1      19.0
# 502   20.6    0.044275       41.93     0.573     6.120  76.7      19.0
# 503   23.9    0.058986       41.93     0.573     6.976  91.0      19.0
# 504   22.0    0.103991       41.93     0.573     6.794  89.3      19.0
# 505   19.0    0.046320       41.93     0.573     6.030  80.8      19.0
#
#      poor_prop airport  n_hos_beds  n_hot_rooms       waterbody  rainfall  \
# 0         4.98     YES       5.480     11.19200           River        23
# 1         9.14      NO       7.332     12.17280            Lake        42
# 2         4.03      NO       7.394     46.19856            None        38
# 3         2.94     YES       9.268     11.26720            Lake        45
# 4         5.33      NO       8.824     11.28960            Lake        55
# ..         ...     ...         ...          ...             ...       ...
# 501       9.67      NO       9.348     12.17920  Lake and River        27
# 502       9.08     YES       6.612     13.16480  Lake and River        20
# 503       5.64      NO       5.478     12.19120            None        31
# 504       6.48     YES       7.940     15.17600            None        47
# 505       7.88     YES      10.280     10.15200            None        45
#
#         parks  avg_dist
# 0    0.049347    4.0875
# 1    0.046146    4.9675
# 2    0.045764    4.9675
# 3    0.047151    6.0650
# 4    0.039474    6.0625
# ..        ...       ...
# 501  0.056006    2.4775
# 502  0.059903    2.2875
# 503  0.057572    2.1675
# 504  0.060694    2.3900
# 505  0.060336    2.5050
#
# [506 rows x 15 columns]

# %%
data = pd.get_dummies(data, columns=['airport','waterbody'], drop_first=True)

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  ...  n_hos_beds  n_hot_rooms  rainfall  bus_ter     parks  \
# 0   4.18   4.01  ...       5.480     11.19200        23      YES  0.049347
# 1   5.12   5.06  ...       7.332     12.17280        42      YES  0.046146
# 2   5.01   4.97  ...       7.394     46.19856        38      YES  0.045764
# 3   6.16   5.96  ...       9.268     11.26720        45      YES  0.047151
# 4   6.37   5.86  ...       8.824     11.28960        55      YES  0.039474
#
#   avg_dist  airport_YES  waterbody_Lake and River  waterbody_None  \
# 0   4.0875            1                         0               0
# 1   4.9675            0                         0               0
# 2   4.9675            0                         0               1
# 3   6.0650            1                         0               0
# 4   6.0625            0                         0               0
#
#    waterbody_River
# 0                1
# 1                0
# 2                0
# 3                0
# 4                0
#
# [5 rows x 22 columns]

# %%
data.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# dist1                     0.251355   -0.587703   -0.706481 -0.768589
# dist2                     0.249459   -0.586127   -0.707956 -0.769724
# dist3                     0.246650   -0.587988   -0.707566 -0.769157
# dist4                     0.248200   -0.580101   -0.705819 -0.764873
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hos_beds                0.108880   -0.004089    0.005799 -0.049553
# n_hot_rooms               0.017007    0.056570   -0.003761  0.007238
# rainfall                 -0.042190    0.076775    0.055401  0.087480
# parks                    -0.391574    0.638951    0.707635  0.915544
# avg_dist                  0.249289   -0.586371   -0.708022 -0.769247
# airport_YES               0.182867   -0.134486   -0.115401 -0.073903
# waterbody_Lake and River -0.037497    0.009076    0.051649  0.013849
# waterbody_None           -0.077478    0.077487    0.086958  0.068554
# waterbody_River           0.071751   -0.060099   -0.098976 -0.037772
#
#                           room_num       age     dist1     dist2     dist3  \
# price                     0.696304 -0.377999  0.251355  0.249459  0.246650
# crime_rate               -0.288784  0.559591 -0.587703 -0.586127 -0.587988
# resid_area               -0.391676  0.644779 -0.706481 -0.707956 -0.707566
# air_qual                 -0.302188  0.731470 -0.768589 -0.769724 -0.769157
# room_num                  1.000000 -0.240265  0.208464  0.203981  0.201907
# age                      -0.240265  1.000000 -0.746904 -0.746493 -0.747021
# dist1                     0.208464 -0.746904  1.000000  0.997905  0.997735
# dist2                     0.203981 -0.746493  0.997905  1.000000  0.998097
# dist3                     0.201907 -0.747021  0.997735  0.998097  1.000000
# dist4                     0.205397 -0.746707  0.994073  0.994003  0.994126
# teachers                  0.355501 -0.261515  0.232834  0.233707  0.233588
# poor_prop                -0.613808  0.602339 -0.498823 -0.495693 -0.494290
# n_hos_beds                0.032009 -0.021012 -0.030365 -0.031071 -0.028315
# n_hot_rooms               0.014583  0.013918 -0.025398 -0.021263 -0.019994
# rainfall                 -0.063891  0.063932 -0.036408 -0.036966 -0.040764
# parks                    -0.282817  0.673850 -0.706319 -0.708237 -0.709346
# avg_dist                  0.205241 -0.747906  0.998933  0.999007  0.998998
# airport_YES               0.163774  0.005101  0.025208  0.020056  0.020195
# waterbody_Lake and River  0.010554 -0.004354 -0.023236 -0.024103 -0.023102
# waterbody_None           -0.052579  0.092693 -0.044592 -0.046974 -0.046268
# waterbody_River           0.046251 -0.088609  0.030763  0.030566  0.033634
#
#                              dist4  ...  poor_prop  n_hos_beds  n_hot_rooms  \
# price                     0.248200  ...  -0.740836    0.108880     0.017007
# crime_rate               -0.580101  ...   0.608970   -0.004089     0.056570
# resid_area               -0.705819  ...   0.603800    0.005799    -0.003761
# air_qual                 -0.764873  ...   0.590879   -0.049553     0.007238
# room_num                  0.205397  ...  -0.613808    0.032009     0.014583
# age                      -0.746707  ...   0.602339   -0.021012     0.013918
# dist1                     0.994073  ...  -0.498823   -0.030365    -0.025398
# dist2                     0.994003  ...  -0.495693   -0.031071    -0.021263
# dist3                     0.994126  ...  -0.494290   -0.028315    -0.019994
# dist4                     1.000000  ...  -0.496084   -0.021534    -0.016003
# teachers                  0.228256  ...  -0.374044   -0.008056    -0.037007
# poor_prop                -0.496084  ...   1.000000   -0.066008     0.017036
# n_hos_beds               -0.021534  ...  -0.066008    1.000000    -0.003130
# n_hot_rooms              -0.016003  ...   0.017036   -0.003130     1.000000
# rainfall                 -0.032937  ...   0.057770    0.056867     0.006498
# parks                    -0.703508  ...   0.552310   -0.071272     0.023757
# avg_dist                  0.997042  ...  -0.496967   -0.027871    -0.020700
# airport_YES               0.020022  ...  -0.095054   -0.006365    -0.055338
# waterbody_Lake and River -0.014671  ...   0.020620    0.059482     0.014755
# waterbody_None           -0.051274  ...   0.095352   -0.003632     0.023307
# waterbody_River           0.033829  ...  -0.109004   -0.074148    -0.064096
#
#                           rainfall     parks  avg_dist  airport_YES  \
# price                    -0.042190 -0.391574  0.249289     0.182867
# crime_rate                0.076775  0.638951 -0.586371    -0.134486
# resid_area                0.055401  0.707635 -0.708022    -0.115401
# air_qual                  0.087480  0.915544 -0.769247    -0.073903
# room_num                 -0.063891 -0.282817  0.205241     0.163774
# age                       0.063932  0.673850 -0.747906     0.005101
# dist1                    -0.036408 -0.706319  0.998933     0.025208
# dist2                    -0.036966 -0.708237  0.999007     0.020056
# dist3                    -0.040764 -0.709346  0.998998     0.020195
# dist4                    -0.032937 -0.703508  0.997042     0.020022
# teachers                 -0.046699 -0.187004  0.232452     0.069437
# poor_prop                 0.057770  0.552310 -0.496967    -0.095054
# n_hos_beds                0.056867 -0.071272 -0.027871    -0.006365
# n_hot_rooms               0.006498  0.023757 -0.020700    -0.055338
# rainfall                  1.000000  0.070181 -0.036834    -0.005484
# parks                     0.070181  1.000000 -0.707924    -0.052503
# avg_dist                 -0.036834 -0.707924  1.000000     0.021402
# airport_YES              -0.005484 -0.052503  0.021402     1.000000
# waterbody_Lake and River  0.106235  0.013265 -0.021320    -0.070341
# waterbody_None           -0.017120  0.070817 -0.047342     0.004617
# waterbody_River          -0.043637 -0.048862  0.032247     0.017341
#
#                           waterbody_Lake and River  waterbody_None  \
# price                                    -0.037497       -0.077478
# crime_rate                                0.009076        0.077487
# resid_area                                0.051649        0.086958
# air_qual                                  0.013849        0.068554
# room_num                                  0.010554       -0.052579
# age                                      -0.004354        0.092693
# dist1                                    -0.023236       -0.044592
# dist2                                    -0.024103       -0.046974
# dist3                                    -0.023102       -0.046268
# dist4                                    -0.014671       -0.051274
# teachers                                 -0.046981       -0.104450
# poor_prop                                 0.020620        0.095352
# n_hos_beds                                0.059482       -0.003632
# n_hot_rooms                               0.014755        0.023307
# rainfall                                  0.106235       -0.017120
# parks                                     0.013265        0.070817
# avg_dist                                 -0.021320       -0.047342
# airport_YES                              -0.070341        0.004617
# waterbody_Lake and River                  1.000000       -0.268471
# waterbody_None                           -0.268471        1.000000
# waterbody_River                          -0.304095       -0.500192
#
#                           waterbody_River
# price                            0.071751
# crime_rate                      -0.060099
# resid_area                      -0.098976
# air_qual                        -0.037772
# room_num                         0.046251
# age                             -0.088609
# dist1                            0.030763
# dist2                            0.030566
# dist3                            0.033634
# dist4                            0.033829
# teachers                         0.094256
# poor_prop                       -0.109004
# n_hos_beds                      -0.074148
# n_hot_rooms                     -0.064096
# rainfall                        -0.043637
# parks                           -0.048862
# avg_dist                         0.032247
# airport_YES                      0.017341
# waterbody_Lake and River        -0.304095
# waterbody_None                  -0.500192
# waterbody_River                  1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(),annot=True, cmap="BuPu" )
plt.ylim(30,0)
# Out:
# (30, 0)

# %%
del data['parks']

# %%
data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  ...  poor_prop  n_hos_beds  n_hot_rooms  rainfall  bus_ter  \
# 0   4.18   4.01  ...       4.98       5.480     11.19200        23      YES
# 1   5.12   5.06  ...       9.14       7.332     12.17280        42      YES
# 2   5.01   4.97  ...       4.03       7.394     46.19856        38      YES
# 3   6.16   5.96  ...       2.94       9.268     11.26720        45      YES
# 4   6.37   5.86  ...       5.33       8.824     11.28960        55      YES
#
#   avg_dist  airport_YES  waterbody_Lake and River  waterbody_None  \
# 0   4.0875            1                         0               0
# 1   4.9675            0                         0               0
# 2   4.9675            0                         0               1
# 3   6.0650            1                         0               0
# 4   6.0625            0                         0               0
#
#    waterbody_River
# 0                1
# 1                0
# 2                0
# 3                0
# 4                0
#
# [5 rows x 21 columns]
